# %% [markdown]
# # Projeto 2 - Classificador Automático de Sentimento
#
# Você foi contratado por uma empresa parar analisar como os clientes estão reagindo a um determinado produto no Twitter. A empresa deseja que você crie um programa que irá analisar as mensagens disponíveis e classificará como "relevante" ou "irrelevante". Com isso ela deseja que mensagens negativas, que denigrem o nome do produto, ou que mereçam destaque, disparem um foco de atenção da área de marketing.<br /><br />
# Como aluno de Ciência dos Dados, você lembrou do Teorema de Bayes, mais especificamente do Classificador Naive-Bayes, que é largamente utilizado em filtros anti-spam de e-mails. O classificador permite calcular qual a probabilidade de uma mensagem ser relevante dadas as palavras em seu conteúdo.<br /><br />
# Para realizar o MVP (*minimum viable product*) do projeto, você precisa implementar uma versão do classificador que "aprende" o que é relevante com uma base de treinamento e compara a performance dos resultados com uma base de testes.<br /><br />
# Após validado, o seu protótipo poderá também capturar e classificar automaticamente as mensagens da plataforma.
#
# ## Informações do Projeto
#
# Prazo: 19/Set até às 23:59.<br />
# Grupo: 2 ou 3 pessoas - grupos com 3 pessoas terá uma rubrica diferenciada.<br /><br />
# Entregáveis via GitHub:
# * Arquivo notebook com o código do classificador, seguindo as orientações abaixo.
# * Arquivo Excel com as bases de treinamento e teste totalmente classificado.
#
# **NÃO gravar a key do professor no arquivo**
#
#
# ### Entrega Intermediária: Check 1 - APS 2
#
# Até o dia 10/Set às 23:59, xlsx deve estar no Github com as seguintes evidências:
#
#   * Produto escolhido.
#   * Arquivo Excel contendo a base de treinamento e a base de testes já classificadas.
#
# Sugestão de leitura:<br />
# https://monkeylearn.com/blog/practical-explanation-naive-bayes-classifier/

# %% [markdown]
# ## Grupo: ##
# Enrico Aloisi Nardi
#
# Evandro Romeiro Fontana
#
# Jadson da Silva Oliveira de Jesus

# %% [markdown]
# ___
#
# ## Parte I - Adquirindo a Base de Dados
#
# Acessar o notebook **Projeto-2-Planilha** para realizar a coleta dos dados. O grupo deve classificar os dados coletados manualmente.

# %% [markdown]
# ___
# ## Parte II - Montando o Classificador Naive-Bayes
#
# Com a base de treinamento montada, comece a desenvolver o classificador. Não se esqueça de implementar o Laplace Smoothing (https://en.wikipedia.org/wiki/Laplace_smoothing).
#
# Opcionalmente:
# * Limpar as mensagens removendo os caracteres: enter, :, ", ', (, ), etc. Não remover emojis.<br />
# * Corrigir separação de espaços entre palavras e/ou emojis.
# * Propor outras limpezas/transformações que não afetem a qualidade da informação.
#
# Escreva o seu código abaixo:

# %%
import pandas as pd
import re

# %%
#Abrindo o arquivo excel
dados= pd.read_excel("tweets_Nintendo_201809042125.xlsx")

#Excluindo colunas e linhas que não serão utilizadas
dados_R= dados.drop(['Classificação (R I)','Classificação (B M)'], axis=1)

dados_limpos = {}
frases = []
classi = []

dados_limpos["Treinamento"] = frases
dados_limpos["Classificacao"] = classi

#Limpando a base de dados -ou seja, excluindo links de vídeos, rt's e @'s-
for i in range(len(dados_R['Treinamento'])):
    Tweet = dados_R.iloc[i]['Treinamento']
    apaga_tudo = re.sub('https://[^\s]+','',Tweet)
    apaga_tudo = re.sub('@[^\s]+','',apaga_tudo)
    apaga_tudo = re.sub('^de','',apaga_tudo)
    apaga_tudo = re.sub('^rt','',apaga_tudo)
    apaga_tudo = re.sub('[^A-Za-z ãõêáí]','',apaga_tudo)
    frases.append(apaga_tudo)
    classi.append(dados_R.iloc[i]['Classificação por Subtopicos (MR, R, N, I, MI)'])

#novos_dados= pd.DataFrame.from_dict(dados_limpos, orient='index')
#novos_dados= novos_dados.T
dados_limpos
# Out:
# {'Classificacao': ['R',
#   'N',
#   'R',
#   'I',
#   'I',
#   'R',
#   'R',
#   'R',
#   'MI',
#   'MI',
#   'N',
#   'MR',
#   'N',
#   'MR',
#   'MR',
#   'MR',
#   'MR',
#   'N',
#   'MR',
#   'MR',
#   'MI',
#   'MR',
#   'R',
#   'I',
#   'N',
#   'N',
#   'MR',
#   'MR',
#   'N',
#   'N',
#   'R',
#   'N',
#   'I',
#   'MR',
#   'R',
#   'MI',
#   'R',
#   'I',
#   'MR',
#   'MI',
#   'MI',
#   'N',
#   'N',
#   'MR',
#   'MR',
#   'MR',
#   'R',
#   'MI',
#   'N',
#   'I',
#   'MR',
#   'R',
#   'R',
#   'I',
#   'MR',
#   'MI',
#   'R',
#   'R',
#   'R',
#   'R',
#   'R',
#   'I',
#   'I',
#   'R',
#   'R',
#   'I',
#   'MR',
#   'R',
#   'R',
#   'MI',
#   'R',
#   'R',
#   'I',
#   'I',
#   'MR',
#   'R',
#   'I',
#   'R',
#   'R',
#   'MR',
#   'R',
#   'MI',
#   'MR',
#   'R',
#   'R',
#   'R',
#   'MI',
#   'MR',
#   'MR',
#   'R',
#   'R',
#   'N',
#   'R',
#   'N',
#   'R',
#   'MR',
#   'R',
#   'R',
#   'R',
#   'MI',
#   'MR',
#   'MR',
#   'R',
#   'R',
#   'N',
#   'MR',
#   'MR',
#   'N',
#   'R',
#   'R',
#   'MR',
#   'R',
#   'MI',
#   'R',
#   'N',
#   'R',
#   'MR',
#   'I',
#   'N',
#   'MI',
#   'MR',
#   'R',
#   'MR',
#   'R',
#   'MI',
#   'R',
#   'R',
#   'R',
#   'R',
#   'N',
#   'R',
#   'N',
#   'R',
#   'MR',
#   'MR',
#   'MR',
#   'R',
#   'N',
#   'R',
#   'R',
#   'R',
#   'MR',
#   'MI',
#   'R',
#   'MR',
#   'MI',
#   'MR',
#   'MR',
#   'N',
#   'R',
#   'MI',
#   'MR',
#   'R',
#   'I',
#   'MR',
#   'R',
#   'R',
#   'MI',
#   'N',
#   'I',
#   'N',
#   'R',
#   'R',
#   'R',
#   'I',
#   'R',
#   'I',
#   'N',
#   'R',
#   'MI',
#   'I',
#   'I',
#   'I',
#   'R',
#   'R',
#   'R',
#   'R',
#   'R',
#   'MR',
#   'MI',
#   'MI',
#   'N',
#   'MR',
#   'I',
#   'N',
#   'R',
#   'R',
#   'I',
#   'R',
#   'R',
#   'N',
#   'R',
#   'R',
#   'R',
#   'R',
#   'N',
#   'N',
#   'N',
#   'R',
#   'MR',
#   'R',
#   'R',
#   'N',
#   'R',
#   'N',
#   'MR',
#   'MR',
#   'R',
#   'N',
#   'R',
#   'MI',
#   'MI',
#   'MI',
#   'R',
#   'R',
#   'R',
#   'R',
#   'N',
#   'I',
#   'I',
#   'R',
#   'MI',
#   'MR',
#   'I',
#   'R',
#   'R',
#   'R',
#   'R',
#   'I',
#   'I',
#   'MR',
#   'R',
#   'I',
#   'I',
#   'MR',
#   'I',
#   'R',
#   'MR',
#   'R',
#   'I',
#   'I',
#   'I',
#   'R',
#   'R',
#   'I',
#   'N',
#   'I',
#   'R',
#   'R',
#   'R',
#   'N',
#   'N',
#   'R',
#   'MI',
#   'MR',
#   'R',
#   'MR',
#   'R',
#   'R',
#   'N',
#   'MR',
#   'R',
#   'R',
#   'MR',
#   'N',
#   'I',
#   'MI',
#   'N',
#   'I',
#   'MR',
#   'N',
#   'R',
#   'R',
#   'R',
#   'R',
#   'MR',
#   'MR',
#   'MR',
#   'R',
#   'R',
#   'I',
#   'N',
#   'MR',
#   'R',
#   'MI',
#   'R',
#   'I',
#   'N',
#   'R',
#   'R',
#   'R',
#   'R',
#   'R',
#   'N',
#   'N',
#   'MR',
#   'MI',
#   'I',
#   'N',
#   'R'],
#  'Treinamento': ['novidades de setembro danintendo  ',
#   '       bugou o polystation esquentou o playstation travou o nintendo nenhuma dessas serviu pra esse rapaz',
#   'ark survival evolved  anunciado para switch confira o jogo em aão em um vídeo  ',
#   'nintendo ',
#   '  mario tennis nintendo  ',
#   'adicionei um vídeo a uma playlist   nintendo gamecube  somente medias   com d box',
#   'i liked a  video  oficial novo jogo da nintendo mobile para celular android e ios  pr registro',
#   'gostei de um vídeo   gui bob   tutorial completo  baixe jogos updates e dlcs de nintendo',
#   ' nintendo',
#   '  nintendo',
#   'fumando um skunkzinho e zerando top gear de super nintendo enquanto meu produtor mixa meus sons',
#   'como se esse evento já não fosse difícil normalmente n porraaaaaa nintendo fidida ',
#   'gostei de um vídeo   gear solid the twin snakes  nintendo gamecube  rapidinha vgdb ',
#   'i added a video to a  playlist  dragalia lost  novo rpg da nintendo com gráficos excelentes',
#   '  tenho os  vídeos games da atual geraão  ps pro x box one x e nintendo switch agora sai uma porra de uma matria que v',
#   ' ainda continuo jogando jogos de nes no nes rs vou mandar esse feedback pra nintendo quem mandou eles fazerem um vídeo game bom que dura muito mais de vinte anos comigo',
#   'charles martinet dublador de mario e luigi confirma presena na bgs   ',
#   ' será temático de nintendo v',
#   'saudade do nintendo ',
#   'esses dias resolvi fazer mirror de um site de roms pra arquivar aqui antes que a nintendo tire tudo do ar faz mais de uma semana que estou baixando tudo',
#   'recuse imitaõesjmemes memesj jornaljogaojogo ps xbox natalidade geek nerd j xboxone nintendo ',
#   'então pessoas eu queria jogar um animal croassing kk mas eu não tenho nenhum nintendo ds e o meu ds morreu ',
#   '  pauline pauline nintendo art fanart mariobros supermario mario ',
#   'gostei de um vídeo   como comprar dbito crdito cardsps xbox one e nintendo switch',
#   '  vendonintendo dsi xl usadoalgumas marcas de uso porm funciona perfeitamenteacompanha case para guardar e caneta re',
#   '  segundadetremurasdv a partir de agora o termo crush esta extintosubstitutos aceitáveisprometidafamigeradanintendo s',
#   ' esse vídeo ainda não assisti vou correndo no seu canal pra ver mas pra ser sincera quanto mais a nintendo enrolar mais eu vou gostar se  que você me entende  kkkkkkkkk',
#   'análise bridge constructor portal chega ao switch em um port malotimizado  ',
#   '  nintendo  e  day  nintendotreehouse nintendoe nintendoswitch switch nintendo e',
#   ' abemus nintendo ',
#   '  curiosidade   brinquedos doces herois que fizeram a cabea das crianas de várias geraões no passado você se lembra',
#   '  vendonintendo dsi xl usadoalgumas marcas de uso porm funciona perfeitamenteacompanha case para guardar e caneta re',
#   '  ontem fui jogar fortnite nao acertei como q atira e constroi muro mira nos cara ao mesmo tempo plmdds  muita coisaeu sou da',
#   '  tenho os  vídeos games da atual geraão  ps pro x box one x e nintendo switch agora sai uma porra de uma matria que v',
#   'mario kart  episdio  copaflor ',
#   'nintendo',
#   'adicionei um vídeo a uma playlist   tirar o amarelo do super nintendo dreamcast sega saturn e ps',
#   ' nintendo gamecubenintendo ds',
#   'dicas do jogo luigis mansion para o console nintendo game cube cdigos  cheats neville ',
#   'nintendo  gtgt',
#   ' nintendo',
#   '  vendonintendo dsi xl usadoalgumas marcas de uso porm funciona perfeitamenteacompanha case para guardar e caneta re',
#   '  vendonintendo dsi xl usadoalgumas marcas de uso porm funciona perfeitamenteacompanha case para guardar e caneta re',
#   'mario bros estrenará cooperativo online gracias a nintendo switch online ',
#   ' não pblica uma piada dessas porque no final eles sempre deixam a gente de boca aberta com um jogo retro nintendo fudido',
#   'hoje ninjin da  foi lanado para nintendo switch o jogo no estilo beat em up acompanha a aventura de ninjas enfrentando diversos inimigos ',
#   'valkyria chronicles  terá oito expansões de contedo at o final do ano ',
#   '  trad    segundo fansign do loonap o que mais interessa a hyunjin ultimamentehyunjin tabuleiroslongboardc',
#   '  vendonintendo dsi xl usadoalgumas marcas de uso porm funciona perfeitamenteacompanha case para guardar e caneta re',
#   '    nintendo',
#   '  o mais novo lanamento da  the messenger já está disponível para nintendo switch e pc gamefmnews ',
#   '  nintendo  ',
#   '  nintendo  e  nintendodirect nintendoe nintendoswitch nintendods e e deadar',
#   '  pois  gamer gaming videogames jogos ps xbox nintendo ',
#   'nessa madrugada tava jogando super mario d world com o lindo do  via parsec eu compartilhando meu pc com ele via streaming e mano esse jogo fica magnifico jogando por multiplayer srio seria uma loucura a nintendo não portar esse game pro switch b ',
#   'resumo nindies showcase confira as novidades anunciadas na apresentaão  ',
#   'nintendo explain nintendo',
#   'quem deixou a nintendo reescrever a bíblia ',
#   ' kkkkkrrrrssss tudo mas tudinho virtual bilhões em propagandas pra convencer e mostrar ser realnem a nintendo e a sony conseguem fazer o mesmo nos games',
#   'soma bringer uma dica que peguei na net para nintendo ds ',
#   'gostei de um vídeo   cast  tmnt turtle in time  parte   super nintendo',
#   '  ontem fui jogar fortnite nao acertei como q atira e constroi muro mira nos cara ao mesmo tempo plmdds  muita coisaeu sou da',
#   'tem uns do super nintendo ai q eu joguei mtttt ',
#   '  lanamentos de games setembro  via    novos ps xbox',
#   'stacados de nintendo eshop agosto  ',
#   ' nintendo tinha que pagar pra ele ser streamer oficial do jogo',
#   'a maior gastura que eu sinto  saber que existe mario kart pra todos os consoles da nintendo menos pro nintendinho',
#   'gostei de um vídeo   com  roms de nintendo ds tb',
#   '  há exatos  anos era lanado teenage mutant ninja turtles tournament fighters para o super nintendonintendo tmnt s',
#   'nintendo ',
#   '  e quem não fazia isso não  mesmo gamer gaming videogames jogos ps xbox nintendo ',
#   'gostei de um vídeo   nintendo gamecube  somente medias   com d box thema ',
#   ' quando eu tinhas uns  anos estava jogando alegremente no meu nintendo  e nao deixei meu irmao jogar e ele mijou no videogame',
#   'tshirt mario  lunch box nintendo    sowia  ',
#   'imagino se tivesse a probabilidade de portar esse game pra um nintendo switchseria muito impressionante mas gb de ram  muito pouco',
#   'estava andando de boa  quando  não pra um nintendo  no lixo    vamos ver se funciona ',
#   ' do jovem nerd nintendo e chaves tb mas sou mesmo',
#   'super nintendo game system  ',
#   '  nintendo direct e nintendos press conference at e ',
#   ' aí vão e detonam os sites de emulaão nintendo  daora mas peca bastante em alguns pontos',
#   'gostei de um vídeo   warriors  parte  link o escolhido  nintendo switch  playthrough',
#   ' hehnintendo color sp for men',
#   ' eu comprei um nintendo switch s que não estou conseguindo entrar no eshop dele fica na tela de inserir um cdigo de download o que  eu fao  estou fazendo alguma coisa errado ',
#   'nintendo classic mini nintendo entertainment system nintendo   ',
#   'observer  trailer de anuncio  nintendo switchobserver nintendoswitch  ',
#   'não vai ter eu ganhando um nintendo switch no natal ',
#   '   nintendo',
#   'nintendo lanou uma atualizaão para a wii u ',
#   ' o link to the past to s nintendo  um horror',
#   'i liked a  video  desbloqueio nintendo switch sem usar jig e injetar payload com modchip programável',
#   'caralho e pensar que eu to pesquisando preo de nintendo  sendo que eu tinha um com controle do pikachu que veio no pokmon stadium  e minha mãe deu ele sem me avisar',
#   'ofertadestacada nintendo switch pro controller   pesos ',
#   ' me chama p joga nintendo',
#   '  vendonintendo dsi xl usadoalgumas marcas de uso porm funciona perfeitamenteacompanha case para guardar e caneta re',
#   'wii u recebe nova atualizaão de firmware ',
#   'nintendo cendo nintendo ',
#   'gostei de um vídeo   mario party  gameplay nintendo switch full hd fps',
#   '  edião de mario bros do nintendo switch online apresenta modo coop online    nintendo https',
#   'emulador de nintendo switchyuzu  progresso realmente absurdo  via ',
#   'aviso do bosscrditos na imagemsiga  alternativanerd mundogamer games gamer rpg skyrim elderscrolls witcher ps xbox nintendo switch ',
#   '  nintendo switch e jogos indies uma mão que lava a outra  via ',
#   '  há exatos  anos era lanado teenage mutant ninja turtles tournament fighters para o super nintendonintendo tmnt s',
#   '  nintendo toys flyer november  japan ',
#   ' muito doido perceber que o nintendo ds tá rodando um monte de remake de ps',
#   ' nintendo ',
#   ' provavelmente ele s precisa ser desligado por completo pra ser reiniciado tenta colocar e tirar elw da dock e se nao funcionar segurar o botao de power por  segundos',
#   ' calma rapaz esse negcio de internet eh novidade pra nintendo hahahahahahahahahahah',
#   '  oi gente live de que posso fazer lolhearthstonefortnitezelda no nintendo switch',
#   'gostei de um vídeo   assaltado uma mulher roubou meu nintendo ',
#   'vou vender meu teclado e meu nintendo pra comprar roupa a q pinto cheguei',
#   '  nintendo lana caixa de papelão para guardar papelões do labo  ',
#   '  super smash bros ultimate pro controller para nintendo switch ',
#   'novo controle xbox one elite branco incrível gow e destiny  de graa e carro do capitão amrica  gift cards  cartão da psn xbox live steam apple google play nintendo  rixty e mais gcm games   ',
#   'pauline pauline nintendo art fanart mariobros supermario mario ',
#   '  vendonintendo dsi xl usadoalgumas marcas de uso porm funciona perfeitamenteacompanha case para guardar e caneta re',
#   'lanamentos de games setembro  via    novos ps xboxone nintendo steam pcgaming youtuber',
#   '  as vezes parece que a nintendo ainda ta nos anos ',
#   ' pq q nunes tá exibindo o nintendo dele quem julia tá segurando oq lara tá fazendo q sinal o menino de vermelho tá fazendo',
#   'gostei de um vídeo   mario gets a nintendo switch',
#   ' humnão tenho nintendoqueria saber como jogar sem sou meio boc pra jogo kkkk',
#   '  como está sua expectativa para o servio online da nintendo que lanará esse mês de setembro',
#   'the messenger  uma excelente aventura d que se inspira em ninja gaiden e brilha com gráficos retr e controles afiados leia nosso review do primeiro game do estdio  ',
#   'esses bundles do super nintendo eram bacanas lembrei do meu saudoso pai quando ele comprou no natal de  ',
#   '  pauline pauline nintendo art fanart mariobros supermario mario ',
#   '  nintendo',
#   'nintendo switch  consola mais vendida no japão pelo sexto mês seguido ',
#   'vem gente supermariomaker ',
#   ' peguei a boa fase do nintendo mega drive ps ps os vídeos games mais novos não me chamaram atenão tenho porm nem ligo kk',
#   ' modern nintendo',
#   ' mas o jogo  de nintendo ds s to dizendo pra vc catar vídeo pra ver como  o jogo q',
#   'gostei de um vídeo   novo jogo da nintendo mobile para celular android e ios  pr registro',
#   '  nintendo news sept  super mario party  nintendo minute nintendo labo   ',
#   'quer baixar capas cover para os jogos de nintendo wii e game cube acesse o gametdb ',
#   'fui pesquisar o preo do nintendo switch ',
#   '  sinceramente a nica mudana que consigo imaginar  que agora terei que pagar  com relaão ao servio não imagino grandes mudanas  vai ser apenas uma conta a mais ',
#   ' o pokebank deve ser usado para a transferência dos pokemons do ds para o nintendo switch isso que eu vi no frum do ',
#   ' jogos novos da nintendo estão timos',
#   ' hoje não vou dar pião porque t na sequela mas sextona nois trava o nintendo',
#   'adicionei um vídeo a uma playlist   jogo chato contra nintendo',
#   ' nintendo fc',
#   '  falta pouco pra gente saber todos os incríveis detalhes do nintendo switch online e ter essa experiência maravilhosa aqui',
#   ' tem alguma coisa mas  em ds pra flashcart dá pra converter pra cia e não  completo acho que ainda dá pra baixar os cia direto da cdn da nintendo though',
#   'manoooo e o meu pai q fez igual com o nintendo  do meu irmão quando a gente era pirralho igual ',
#   '  há exatos  anos era lanado teenage mutant ninja turtles tournament fighters para o super nintendonintendo tmnt s',
#   '  tenho os  vídeos games da atual geraão  ps pro x box one x e nintendo switch agora sai uma porra de uma matria que v',
#   'gozada legal   nintendo wii gay porn amadoras dando o cuzinho badjojo videos amateus punhetas',
#   '  tenho os  vídeos games da atual geraão  ps pro x box one x e nintendo switch agora sai uma porra de uma matria que v',
#   'se pudesse eu dava um nintendo switch pra td mundo que gosto',
#   'hyper light drifter  anunciado para switch  ',
#   ' nossa num lembrava o nome tive que por jogo de corrida do super nintendo hahaha eu s alugava a fita acho',
#   'nintendo',
#   ' tudo isso pra ter motivo pra boicotar as room online no futuro e dizer que os fãs estão se apropriando de suas franquias ou alguma dessas respostas típica da nintendo de quando um fã tenta fazer algo legal pelas franquias que adora',
#   'nintendo wii u recebe nova atualizaão de firmware passando para a versão  ',
#   'va a estar para nintendo switch ',
#   'nintendo me deixa evoluir meus pokmon de graa no lets go eu te imploro eu sou doente ',
#   'ouvindo whats up do  non blondes e voltou  anos para o passado mãe cadê meu super nintendo',
#   'mario kart  deluxe nintendo switch taa ovo cc de moto com o luigi  vídeo game para crianas  via',
#   ' nintendo  ',
#   'fazer uma farofinha aqui pra minha crush ao som das msicas de jogos da nintendo ',
#   'actraiser  nintendo super nes    ',
#   '  vendonintendo dsi xl usadoalgumas marcas de uso porm funciona perfeitamenteacompanha case para guardar e caneta re',
#   '  mais uma semana liderada por jogos lanados no console nintendo switcho console conseguiu a incrível marca de  do',
#   'o mais novo lanamento da  the messenger já está disponível para nintendo switch e pc gamefmnews ',
#   ' espero q eu seja de radical rex de super nintendo v',
#   'oispa nintendo switch',
#   '  amanhã  o lanamento de planet alphadesenvolvedor plataformas ps xbox one pc switchsite ',
#   '  mario tennis nintendo  ',
#   ' nintendo peseteros',
#   '  uai eu jogo muito melhor no controle do nintendo que xbox mesmo inclusive a meia lua sai perfeita',
#   'apr   by salisca yeahs  replies eudedicado a salva  ',
#   ' isso parece um password para o top gear do s nintendo',
#   'mario kart  deluxe nintendo switch   ',
#   '  ontem fui jogar fortnite nao acertei como q atira e constroi muro mira nos cara ao mesmo tempo plmdds  muita coisaeu sou da',
#   'muito massa ver mariokartdeluxe sendo a estrela da cobertura da gamexp isso num país que geralmente não dá o devido valor  nintendo',
#   '  o ano  chegaram da escola sentamse e pegam na nintendo para jogar pokmon diamondlife is great',
#   'vida não  playstation nem nintendo acordem p mundo real',
#   'anos viu aquele jogo novo da nintendonão sou sega',
#   'mario kart no almoo muito obrigado nintendo ',
#   '  se vc te coisas pra jogar não vale a pena mesmo não sei como era no wii u mas no switch sempre tem muitas promoões ainda  meio caro mas  bem melhor do que a nintendo no ds dá uma olhada s nas promos ativas agora',
#   '  nintendo labo developer nintendo ',
#   '  pauline nintendo',
#   ' vc  fanboy da nintendo declarado obvio q vc prefere',
#   '  tenho os  vídeos games da atual geraão  ps pro x box one x e nintendo switch agora sai uma porra de uma matria que v',
#   'mas se eu mudar eu vou perder o que eu tenho no meu my nintendo do ds  pq ele esta no eshop br ',
#   '  moi team nintendo',
#   'nintendo direct essa semana eu vou gostar demais',
#   'super nintendo chalmers  ',
#   ' vou te visitar em denver  verdade esse bileteseu safado',
#   's stalkeio de vez em qnd pra me manter atualizada deus me dibre minha timeline cheia de nintendo switch ',
#   'setembro traz novidades para a nintendo',
#   ' no nintendo forever',
#   'gostei de um vídeo   nintendo switch sem usar jig e injetar payload com modchip',
#   ' lavagem cerebral de s ter consoles da nintendo desde jovem silent hill  joguei recentemente no ps de um amigo',
#   ' eu devia ter feito isso no meu super nintendo ',
#   'nintendo switch já vendeu quase  milhões de unidades no japão games ',
#   'nintendo  promo ',
#   ' o engraado  q jogo no psum cd com jogos de nintendo e mega drive rs rs',
#   'adicionei um vídeo a uma playlist   physical super rare games for nintendo switch',
#   'acho que eu s joguei os dragon quest que sairam pro nintendo ds mas esse dragon quest xi está me deixando muito interessado',
#   ' vsf vc rico tb consoles nintendo compra jogo toda semana',
#   'souotipodepessoaq s vive ostentaão de jogar o campeonato brasileiro joga a noite toda pra zerakkkk tomado caf eu os meu tio e o meu primokkkkk super nintendo e o mito',
#   '  pauline pauline nintendo art fanart mariobros supermario mario ',
#   'oi gente live de que posso fazer lolhearthstonefortnitezelda no nintendo switch',
#   'caraaaa achei meu super nintendo o jogo do looney tunes e aquele duck hunt nes de jogar com a pistolinha  nostalgia',
#   'relatrio do progresso de agosto  dolphin  emulador de nintendo wii e gamecube  via ',
#   'nintendo confirma que não haverá suporte para o switch pro controller em the world ends with you final remix  ',
#   'mario bros estrenará cooperativo online gracias a nintendo switch online ',
#   'gostei de um vídeo   marked for death  announcement trailer  nintendo switch',
#   'roberta ja ate vendeu o nintendo ds',
#   'super nintendo pequenininha vou endividarme  diogo batáguas  dose  via ',
#   ' nintendo nintendo nintendo',
#   ' nintendo',
#   'travis strikes again não  no more heroes  diz suda ',
#   'quando nintendo quando para de mistrio ',
#   'to viciada em mario run novamente ta feliz nintendo',
#   'sei que o sapato não combina mas era quase impossível ter sapato sem ser assinante eu s tinha os do dojo e esseversão vermelha desse que ganha no jogo de club penguin de nintendo wii ',
#   '  pauline pauline nintendo art fanart mariobros supermario mario ',
#   'gostei de um vídeo    novos jogos de setembro  para pc ps xone e nintendo switch melhores',
#   'cazadoraby jonpeitometroid nintendo samusaran ',
#   'nintendo swing anuncio  a travs de ',
#   'tendo rumores de nintendo direct essa semana e eu to aqui rezando pra não ser transmitido por esses dias principalmente na quinta ou sexta pois não vou poder assistir eou cobrir por favor ',
#   'super nintendo ',
#   '  no caso da nintendo não existem trofeus ou conquistas porm progresso e quando vejo uma oportunidade a ser explorada penso que não usurfrui de todo potencial de entretenimento que a nintendo se dedicou a nos entregar são tantos detalhes e carinho em cada jogo',
#   '  nintendo',
#   'alguem me explica porque  que o meu nintendo switch não está a funcionar',
#   'fixingmario encanadormarioodyssey mario artnswitch shigerumiyamoto taxi mariobros supermario gamer nintendo switch art fotografia photography water  porto ',
#   'adicionei um vídeo a uma playlist   retro   disneys aladdin  super nintendo',
#   'adicionei um vídeo a uma playlist   mc donalds mc lanche feliz e nintendo   garimpando',
#   'codeína  pra travar o nintendo viajando pro país das maravilhas',
#   '  congos caper joe amp mac  sur super nintendo',
#   '  sony blah nintendo blah  sou mais xbox agora hahaha aquele',
#   ' isso sem falar no nintendo que tive antes do ps kkkkk',
#   ' queria mais n tenho placa de video fica igual nintendo ',
#   'actraiser  nintendo super nes    ',
#   'nintendo nintendo nada de nada   jepputoamo',
#   '  pois  gamer gaming videogames jogos ps xbox nintendo ',
#   'caf temático que s toca versão de jazz de msica de jogo de nintendo ',
#   ' eita tenta pelo id da nintendo network gabsgabs',
#   'ys viii lacrimosa of dana chegará ao switch em  de junho confira um novo trailer  ',
#   '  ontem fui jogar fortnite nao acertei como q atira e constroi muro mira nos cara ao mesmo tempo plmdds  muita coisaeu sou da',
#   'ya gente hj acordei e fui contra a porta jorrei sangue do nariz e agora fui ao carro buscar o carregador da nintendo e cortei o p lmfao',
#   ' nintendo beste mois',
#   '  sempre que algum vir falar que nintendo switch vale a pena eu vou mostrar essas imagens ',
#   'adicionei um vídeo a uma playlist   nintendo games almost never go on sale',
#   'nintendo wii  ',
#   'gostei de um vídeo   nintendo switch pro controller super smash bros ultimate edition reveal',
#   'nggg nuggan tshirt mario  lunch box nintendo    sowia ',
#   '  wii u recebe nova atualizaão de firmware ',
#   'se você se interessou pelo meu vídeo sobre a guerra da nintendo contra emuladores e roms este aqui explora o tema de emuladores e preservaão histrica de maneira mais profunda recomendo em inglês',
#   '  forgotton annie jogo inspirado pelo studio ghibli chegará ao switch ',
#   'nintendo direct e   via ',
#   'giana sisters twisted dreams owltimate edition confirmada a data de lanamento para o switch  ',
#   ' nos tempos do nintendo wii eu e o  nos reuníamos semanalmente pra jogar wii music que permitia colocar miis temáticos em bandas nossa maior obra foi a all flavio band quando cinco miis do flavio tocavam a pior versão possível do tema de zelda',
#   ' nintendo',
#   ' então vaaarias vezes eu estive a um clique de comprar no wii u mas achei melhor deixar pra quando tivesse o switch e eu vou querer jogar ele inteiro fazendo live aqui no canal então não rola de ser em emulador a nintendo me mata ahahah mas vai ser meu  jogo do switch',
#   '  the messenger  uma excelente aventura d que se inspira em ninja gaiden e brilha com gráficos retr e controles afiados l',
#   ' fala então do novo lanamento da nintendo que  a caixa de papelão para guardar os papelões do nintendo labo ',
#   'sorte que não fiz isso com o meu super nintendo pq senao alem de terem sumido com o meu super nintendo teriam sumido com  reais meus ',
#   ' gradicido mat obrigado por seus insights sobre jogos da nintendo e desejo tudo de bom pra você',
#   '  vendonintendo dsi xl usadoalgumas marcas de uso porm funciona perfeitamenteacompanha case para guardar e caneta re',
#   '  quase a mesma coisa a diferena  que   reais mais barato e os jogos da nintendo me apetecem mais',
#   'não s o melhor videogame da nintendo e sim o melhor console de todos os tempos  ',
#   'edião de mario bros do nintendo switch online apresenta modo coop online    nintendo ',
#   'hoje eu so to a nintendo lanando papelao e chamando de jogo',
#   'novidades de setembro da nintendo  ',
#   '  ontem fui jogar fortnite nao acertei como q atira e constroi muro mira nos cara ao mesmo tempo plmdds  muita coisaeu sou da',
#   '  p z gamer gaming videogames jogos ps xbox nintendo ',
#   ' nintendo comprará a sony',
#   '    nintendo ',
#   'poxa a nintendo poderia criar umas fases s por consideraão',
#   '  retrogaming retrogames retrogamer supernintendo gamersunite rafaeltdonverifique a  maratona de super nintendo  pa',
#   ' r carlos estava pro ps assim como allejo estava pro nintendo hahahaha mas o ps foi o melhor de todos moldava caráter com os bomba patch',
#   '  nintendo toys flyer november  japan ',
#   '  forgotton annie jogo inspirado pelo studio ghibli chegará ao switch ',
#   'forgotton anne  jogo será lanado para nintendo switch  ',
#   ' mds como assim vai se fuder nintendo kkkkkkkkkkkkkk',
#   'qual você consideraria ser a sua melhor experiência  melhor experiência da minha vida foi quando ganhei meu super nintendo ',
#   '  vou guardar  no meu nintendo muleke qnd eu achar vou ficar um nojo',
#   'gostei de um vídeo   novo jogo da nintendo mobile para celular android e ios  pr registro',
#   '  pauline pauline nintendo art fanart mariobros supermario mario ',
#   'adicionei um vídeo a uma playlist   alpha  launch trailer  nintendo switch',
#   '  vendonintendo dsi xl usadoalgumas marcas de uso porm funciona perfeitamenteacompanha case para guardar e caneta re',
#   ' meu dilema  que acho que investi pouco tempo no wii u que tenho aqui com um backlog gigantesco e tudo da nintendo tambm  horrivelmente mais caro',
#   '  os melhores jogos e mais bem avaliados para nintendo wii u ',
#   '  travis strikes again não  no more heroes  diz suda ',
#   'e quem não fazia isso não  mesmo gamer gaming videogames jogos ps xbox nintendo ',
#   'console nintendo switch gb  neon azul e neon vermelho   ano de garantiamais informaões       rua  de setembro  box  ao lado da marilda doces mercadãonintendo switch nintendoswitch mundomagicogame ',
#   ' top  jogos super nintendo ',
#   'clássico do fliperama mario bros terá coop online no switch ',
#   'wii u recebe nova atualizaão de firmware ',
#   ' at hoje jogo zelda botw sim eu tenho pena de zerar kkkk e pretendo completar todas as shrines e korok seeds e confesso que sinto falta dos trofeus queria muito platinar o jogo espero que em  a nintendo lance esse sistema na plataforma ',
#   '  nintendo toys flyer november  japan ',
#   'gostei de um vídeo   rodar jogos de nintendo ds no dsds sem flashcardr twloader',
#   '  vendonintendo dsi xl usadoalgumas marcas de uso porm funciona perfeitamenteacompanha case para guardar e caneta re',
#   'a rockman  x megaman vii x nintendo super famicom game japan snes sfc  ',
#   'pra ns brasileiros mas feito pelos gringos do polygon porque os jogos da nintendo quase nunca entram em promoão  ',
#   ' nintendo',
#   '  ontem fui jogar fortnite nao acertei como q atira e constroi muro mira nos cara ao mesmo tempo plmdds  muita coisaeu sou da',
#   'algum nesse website tem o nintendo switch',
#   'mais  grandes jogos chegando ao nintendo switch em  e comeo de  ']}

# %%
#criação de um dicionário que receberá outros dicionários que contêm a contagem das palavras dada uma determinada classe
d_base={}
d_base['MR']={}
d_base['R']={}
d_base['N']={}
d_base['I']={}
d_base['MI']={}
todas_palavras= []

for k in novos_dados:
    palavras = k.split()
    break
    for p in palavras:
        if p in d_base[IouR]:
            d_base[IouR][p] += 1
        else:
            d_base[IouR][p] = 1
print(palavras)
# Out:
# ['Treinamento']

# %% [markdown]
# ___
# ## Verificando a performance
#
# Agora você deve testar o seu Classificador com a base de Testes.<br /><br />
#
# Você deve extrair as seguintes medidas:
# * Porcentagem de positivos falsos (marcados como relevante mas não são relevantes)
# * Porcentagem de positivos verdadeiros (marcado como relevante e são relevantes)
# * Porcentagem de negativos verdadeiros (marcado como não relevante e não são relevantes)
# * Porcentagem de negativos falsos (marcado como não relevante e são relevantes)
#
# Obrigatório para grupos de 3 alunos:
# * Criar categorias intermediárias de relevância baseado na diferença de probabilidades. Exemplo: muito relevante, relevante, neutro, irrelevante e muito irrelevante.

# %% [markdown]
# ___
# ## Concluindo
#
# Escreva aqui a sua conclusão.<br />
# Faça um comparativo qualitativo sobre as medidas obtidas.<br />
# Explique como são tratadas as mensagens com dupla negação e sarcasmo.<br />
# Proponha um plano de expansão. Por que eles devem continuar financiando o seu projeto?<br />
#
# Opcionalmente:
# * Discorrer por que não posso alimentar minha base de Treinamento automaticamente usando o próprio classificador, aplicado a novos tweets.
# * Propor diferentes cenários de uso para o classificador Naive-Bayes. Cenários sem intersecção com este projeto.
# * Sugerir e explicar melhorias reais no classificador com indicações concretas de como implementar (não é preciso codificar, mas indicar como fazer e material de pesquisa sobre o assunto).
